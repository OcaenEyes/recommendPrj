# %% [markdown]
# ### 实现步骤：
#
# 1. 获取文章列表数据，包括ID、标题、内容
# 2. 使用jieba实现关键词提取
# 3. 查询腾讯word2vec，平均法得到文档embedding
# 4. 对于输入的ID，计算最相似的文章列表

# %% [markdown]
# #### 获取数据

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./dataset/datas/crazyant_blog_articles_wordsegs.csv")

# %%
df
# Out:
#        id                                         post_title  \
# 0      78                     JavaScript对Select的子元素Option的操作
# 1      83  当用header方法输出内容时出现“Cannot modify header informa...
# 2      85                                     linux下禁止机箱蜂鸣方法
# 3      87                     硬盘分区表丢失、修复大事记--分区表修复利器testdisk
# 4      91                                            vi编辑器命令
# ..    ...                                                ...
# 262  2604                            Pandas怎样对每个分组应用apply函数?
# 263  2615                                   推荐系统实现相似推荐的流程和资源
# 264  2623                              文章写的好，但是没人看，原来标题可以这么写
# 265  2629                                             自律使我自由
# 266  2637                                      程序员-颈椎病-该练八段锦
#
#                                                  words
# 0    javascript select 元素 option 操作 javascript 删除 所...
# 1    当用 header 方法 输出 内容 出现 cannot modify header inf...
# 2    linux 禁止 机箱 蜂鸣 方法 图像 界面 注意 图形界面 即使 图像 界面 快捷键 出...
# 3    硬盘分区 丢失 修复 大事记 -- 分区表 修复 利器 testdisk 今天 2009 1...
# 4    vi 编辑器 命令 vi 编辑器 文字说明 模式 命令 模式 编辑 模式 末行 模式 切换 ...
# ..                                                 ...
# 262  pandas 怎样 每个 分组 应用 apply 函数 pandas 怎样 每个 分组 应用...
# 263  推荐 系统 实现 相似 推荐 流程 资源 视频 位于 链接 需要 资源 整理 视频 涉及 相...
# 264  文章 但是 没人 原来 标题 可以 这么 一种 方法 就是 三段式 标题 三段式 来自 百度...
# 265  自律 自由 从来 没有 完全 自由 如果 节制 放纵 自己 大吃大喝 熬夜 玩游戏 那么 导...
# 266                                     程序员 颈椎病 该练 八段锦
#
# [267 rows x 3 columns]

# %%
allwords = set()
for idx,row in df.iterrows():
    allwords.update(row["words"].split(" "))

# %%
len(allwords)
# Out:
# 14871

# %%
# 候选词的embedding
word_embedding = {}
is_first_line = True

# %%
with open("./dataset/datas/small_tencent_embedding.txt",encoding="utf-8") as f:
    tmp = f.readlines()

# %%
tmp[1]
# Out:
# '我们 0.238955 -0.192848 -0.211907 0.150934 0.138219 -0.142815 0.109576 0.237430 0.113313 0.212766 0.185741 -0.072593 -0.038890 -0.148697 0.113447 -0.054734 -0.119707 -0.301614 0.010661 -0.373224 0.046995 -0.040254 0.217435 0.124474 0.107320 -0.154016 -0.214472 -0.026875 0.271341 0.034196 -0.048286 0.135981 -0.159336 0.291878 0.029767 -0.080823 0.075705 0.208965 -0.393423 -0.070348 0.074219 -0.010314 0.555231 0.265382 -0.203183 -0.059019 -0.227729 -0.438141 -0.154139 -0.004460 -0.155796 -0.156204 -0.280239 0.119024 0.270675 0.015977 0.061125 0.106046 0.119620 0.016656 -0.188581 0.195843 0.322265 -0.252883 0.009620 0.211928 -0.061827 0.101208 -0.118682 -0.004104 -0.315729 -0.033734 0.019271 0.093593 -0.038363 0.271059 0.076770 0.187507 0.279387 -0.091230 0.174323 0.263890 0.146483 0.175136 0.250636 -0.268815 -0.242602 0.098451 -0.340867 -0.046590 0.143537 -0.032850 -0.112147 0.059271 0.151730 0.063198 -0.010309 -0.218437 -0.250653 -0.027172 0.099709 0.089741 -0.039581 0.168280 -0.289254 0.112675 0.038056 -0.492440 0.032809 -0.059656 -0.062112 -0.199729 -0.181568 -0.242486 -0.032274 -0.016013 -0.094967 -0.256583 -0.216345 -0.405813 0.046074 -0.383228 -0.132296 -0.141405 0.036089 0.062235 -0.009278 -0.104389 -0.148759 0.223392 -0.115293 0.018296 0.128362 -0.147406 -0.275197 -0.035063 -0.139143 0.048862 -0.120634 -0.029140 -0.286435 -0.276701 -0.221037 -0.014872 -0.111541 -0.187855 0.305286 0.113838 -0.179423 0.218023 0.150745 0.004675 -0.448954 0.051357 -0.141597 0.068116 0.264635 0.025572 0.116729 -0.159488 0.360647 -0.075746 0.090265 0.157042 0.453843 0.074740 -0.149657 0.125378 0.039159 0.095487 -0.052240 0.164203 -0.039177 0.167412 -0.008903 -0.025282 -0.074631 -0.067798 0.095912 0.279136 -0.052315 -0.155109 -0.182204 0.130321 0.056165 -0.232989 -0.186970 0.180461 -0.034499 0.131032 0.156559 0.153899 0.015085 0.019390 0.207332 0.202583 0.235376 -0.256160 -0.141990 0.137744\n'

# %%
tmp[1][:-1].split()
# Out:
# ['我们',
#  '0.238955',
#  '-0.192848',
#  '-0.211907',
#  '0.150934',
#  '0.138219',
#  '-0.142815',
#  '0.109576',
#  '0.237430',
#  '0.113313',
#  '0.212766',
#  '0.185741',
#  '-0.072593',
#  '-0.038890',
#  '-0.148697',
#  '0.113447',
#  '-0.054734',
#  '-0.119707',
#  '-0.301614',
#  '0.010661',
#  '-0.373224',
#  '0.046995',
#  '-0.040254',
#  '0.217435',
#  '0.124474',
#  '0.107320',
#  '-0.154016',
#  '-0.214472',
#  '-0.026875',
#  '0.271341',
#  '0.034196',
#  '-0.048286',
#  '0.135981',
#  '-0.159336',
#  '0.291878',
#  '0.029767',
#  '-0.080823',
#  '0.075705',
#  '0.208965',
#  '-0.393423',
#  '-0.070348',
#  '0.074219',
#  '-0.010314',
#  '0.555231',
#  '0.265382',
#  '-0.203183',
#  '-0.059019',
#  '-0.227729',
#  '-0.438141',
#  '-0.154139',
#  '-0.004460',
#  '-0.155796',
#  '-0.156204',
#  '-0.280239',
#  '0.119024',
#  '0.270675',
#  '0.015977',
#  '0.061125',
#  '0.106046',
#  '0.119620',
#  '0.016656',
#  '-0.188581',
#  '0.195843',
#  '0.322265',
#  '-0.252883',
#  '0.009620',
#  '0.211928',
#  '-0.061827',
#  '0.101208',
#  '-0.118682',
#  '-0.004104',
#  '-0.315729',
#  '-0.033734',
#  '0.019271',
#  '0.093593',
#  '-0.038363',
#  '0.271059',
#  '0.076770',
#  '0.187507',
#  '0.279387',
#  '-0.091230',
#  '0.174323',
#  '0.263890',
#  '0.146483',
#  '0.175136',
#  '0.250636',
#  '-0.268815',
#  '-0.242602',
#  '0.098451',
#  '-0.340867',
#  '-0.046590',
#  '0.143537',
#  '-0.032850',
#  '-0.112147',
#  '0.059271',
#  '0.151730',
#  '0.063198',
#  '-0.010309',
#  '-0.218437',
#  '-0.250653',
#  '-0.027172',
#  '0.099709',
#  '0.089741',
#  '-0.039581',
#  '0.168280',
#  '-0.289254',
#  '0.112675',
#  '0.038056',
#  '-0.492440',
#  '0.032809',
#  '-0.059656',
#  '-0.062112',
#  '-0.199729',
#  '-0.181568',
#  '-0.242486',
#  '-0.032274',
#  '-0.016013',
#  '-0.094967',
#  '-0.256583',
#  '-0.216345',
#  '-0.405813',
#  '0.046074',
#  '-0.383228',
#  '-0.132296',
#  '-0.141405',
#  '0.036089',
#  '0.062235',
#  '-0.009278',
#  '-0.104389',
#  '-0.148759',
#  '0.223392',
#  '-0.115293',
#  '0.018296',
#  '0.128362',
#  '-0.147406',
#  '-0.275197',
#  '-0.035063',
#  '-0.139143',
#  '0.048862',
#  '-0.120634',
#  '-0.029140',
#  '-0.286435',
#  '-0.276701',
#  '-0.221037',
#  '-0.014872',
#  '-0.111541',
#  '-0.187855',
#  '0.305286',
#  '0.113838',
#  '-0.179423',
#  '0.218023',
#  '0.150745',
#  '0.004675',
#  '-0.448954',
#  '0.051357',
#  '-0.141597',
#  '0.068116',
#  '0.264635',
#  '0.025572',
#  '0.116729',
#  '-0.159488',
#  '0.360647',
#  '-0.075746',
#  '0.090265',
#  '0.157042',
#  '0.453843',
#  '0.074740',
#  '-0.149657',
#  '0.125378',
#  '0.039159',
#  '0.095487',
#  '-0.052240',
#  '0.164203',
#  '-0.039177',
#  '0.167412',
#  '-0.008903',
#  '-0.025282',
#  '-0.074631',
#  '-0.067798',
#  '0.095912',
#  '0.279136',
#  '-0.052315',
#  '-0.155109',
#  '-0.182204',
#  '0.130321',
#  '0.056165',
#  '-0.232989',
#  '-0.186970',
#  '0.180461',
#  '-0.034499',
#  '0.131032',
#  '0.156559',
#  '0.153899',
#  '0.015085',
#  '0.019390',
#  '0.207332',
#  '0.202583',
#  '0.235376',
#  '-0.256160',
#  '-0.141990',
#  '0.137744']

# %%
with open("./dataset/datas/small_tencent_embedding.txt",encoding="utf-8") as f:
    for line in f:
        if is_first_line:
            is_first_line = False
            continue
        fields = line[:-1].split()
        if len(fields) != 201:
            continue
        
        word = fields[0]
        if word in allwords:
            word_embedding[word] = np.array([float(x) for x in fields[1:]])

# %%
len(word_embedding)
# Out:
# 11382

# %%
word_embedding["python"]
# Out:
# array([ 0.382475,  0.156139,  0.062302,  0.030984,  0.481495, -0.070564,
#         0.466484,  0.546035, -0.238761, -0.126754,  0.063588,  0.091173,
#        -0.272091, -0.113122,  0.170998, -0.139973, -0.335421, -0.1836  ,
#        -0.119432, -0.026666, -0.524403, -0.290163, -0.495772,  0.136166,
#         0.074637,  0.126304, -0.41948 ,  0.271968,  0.447399,  0.041005,
#        -0.180788,  0.101531,  0.333039,  0.013628,  0.052285, -0.433536,
#         0.494823, -0.29307 , -0.073794,  0.260313, -0.052784, -0.226162,
#         0.791509, -0.203396,  0.059075, -0.082627, -0.423575, -0.371575,
#        -0.568254,  0.134853,  0.174628,  0.138118,  0.059341, -0.405463,
#         0.452836, -0.067161,  0.236258,  0.347981,  0.16007 , -0.213742,
#         0.047517,  0.232295, -0.151182,  0.011967, -0.528855, -0.566595,
#         0.287433,  1.006496,  0.00421 ,  0.031725, -0.543762,  0.194417,
#         0.028565, -0.086813,  0.005247,  0.582514, -0.241997,  0.249292,
#         0.14645 ,  0.213583,  0.241735, -0.29941 , -0.192367,  0.115289,
#         0.193353, -0.717468, -0.139603,  0.110287, -0.104537,  0.076995,
#         0.669608,  0.192023, -0.157454,  0.015251,  0.42727 ,  0.442922,
#        -0.302943, -0.308798, -0.374949, -0.039363, -0.279962, -0.403831,
#        -0.172874, -0.133776, -0.229774,  0.078177,  0.259441, -0.601561,
#         0.506313, -0.105971, -0.13219 , -0.594944,  0.140356, -0.288789,
#        -0.538704,  0.168588,  0.332293, -0.230388,  0.082054, -0.310356,
#         0.419455, -0.522421, -0.115699,  0.164517, -0.069782, -0.157018,
#        -0.334557, -0.251582, -0.590902,  0.226033,  0.398092, -0.091599,
#         0.091727, -0.58307 , -0.336118,  0.156774, -0.143228, -0.177227,
#        -0.074846, -0.185674, -0.314648, -0.515832, -0.202507, -0.496272,
#         0.52302 , -0.452872,  0.142403,  0.745848,  0.39067 ,  0.140554,
#        -0.12223 ,  0.138288,  0.075117, -0.319113,  0.277703,  0.258449,
#        -0.33654 ,  0.349149, -0.191787,  0.049775,  0.687543, -0.03194 ,
#        -0.196278, -0.017717, -0.257426, -0.16031 , -0.462313,  0.046826,
#         0.877917, -0.300582, -0.15293 , -0.06792 ,  0.022872,  0.628877,
#        -0.216007, -0.157061, -0.217871,  0.247333, -0.481145,  0.449098,
#         0.073597, -0.613611,  0.403303,  0.08095 , -0.121972,  0.029561,
#        -0.053261,  0.058306,  0.039042,  0.062777,  0.153255,  0.25143 ,
#         0.047837, -0.003452,  0.474237,  0.277556,  0.559055,  0.138842,
#        -0.240994,  0.649724])

# %% [markdown]
# - 计算每篇文章的doc embedding

# %%
def compute_doc_vector(words):
    words = words.split()
    embeddings = []
    for word in words:
        if word in word_embedding:
            embeddings.append(word_embedding[word])
    return np.sum(embeddings,axis=0) / len(embeddings)

# %%
df["doc_vector"] = df["words"].map(compute_doc_vector)

# %%
df
# Out:
#        id                                         post_title  \
# 0      78                     JavaScript对Select的子元素Option的操作
# 1      83  当用header方法输出内容时出现“Cannot modify header informa...
# 2      85                                     linux下禁止机箱蜂鸣方法
# 3      87                     硬盘分区表丢失、修复大事记--分区表修复利器testdisk
# 4      91                                            vi编辑器命令
# ..    ...                                                ...
# 262  2604                            Pandas怎样对每个分组应用apply函数?
# 263  2615                                   推荐系统实现相似推荐的流程和资源
# 264  2623                              文章写的好，但是没人看，原来标题可以这么写
# 265  2629                                             自律使我自由
# 266  2637                                      程序员-颈椎病-该练八段锦
#
#                                                  words  \
# 0    javascript select 元素 option 操作 javascript 删除 所...
# 1    当用 header 方法 输出 内容 出现 cannot modify header inf...
# 2    linux 禁止 机箱 蜂鸣 方法 图像 界面 注意 图形界面 即使 图像 界面 快捷键 出...
# 3    硬盘分区 丢失 修复 大事记 -- 分区表 修复 利器 testdisk 今天 2009 1...
# 4    vi 编辑器 命令 vi 编辑器 文字说明 模式 命令 模式 编辑 模式 末行 模式 切换 ...
# ..                                                 ...
# 262  pandas 怎样 每个 分组 应用 apply 函数 pandas 怎样 每个 分组 应用...
# 263  推荐 系统 实现 相似 推荐 流程 资源 视频 位于 链接 需要 资源 整理 视频 涉及 相...
# 264  文章 但是 没人 原来 标题 可以 这么 一种 方法 就是 三段式 标题 三段式 来自 百度...
# 265  自律 自由 从来 没有 完全 自由 如果 节制 放纵 自己 大吃大喝 熬夜 玩游戏 那么 导...
# 266                                     程序员 颈椎病 该练 八段锦
#
#                                             doc_vector
# 0    [-0.013126199999999996, -0.03166106249999995, ...
# 1    [0.173896275, -0.12689985, -0.0503381250000000...
# 2    [0.17765841463414633, -0.13135253658536586, -0...
# 3    [0.25020975, -0.19336403888888903, -0.00018789...
# 4    [0.12497060176991134, -0.09836270353982311, 0....
# ..                                                 ...
# 262  [0.06635910714285706, 0.02634534761904762, -0....
# 263  [0.08312790909090909, -0.005004499999999976, -...
# 264  [0.22609510322580648, -0.18270135483870972, -0...
# 265  [0.19995407407407392, -0.30916040740740725, -0...
# 266  [0.58515775, -0.3567525, -0.03915575, -0.25169...
#
# [267 rows x 4 columns]

# %%
article_id = 2583

# %%
df[df["id"] ==2583]["doc_vector"]
# Out:
# 256    [0.005996356060606063, 0.0679557373737372, -0....
# Name: doc_vector, dtype: object

# %%
article_embedding = df[df["id"] ==2583]["doc_vector"].iloc[0]

# %%
type(article_embedding)
# Out:
# numpy.ndarray

# %%
article_embedding.shape
# Out:
# (200,)

# %%
# 余弦相似度
from scipy.spatial import distance

# %%
df["sim_value"] = df["doc_vector"].map(lambda x : 1- distance.cosine(article_embedding,x))

# %%
df
# Out:
#        id                                         post_title  \
# 0      78                     JavaScript对Select的子元素Option的操作
# 1      83  当用header方法输出内容时出现“Cannot modify header informa...
# 2      85                                     linux下禁止机箱蜂鸣方法
# 3      87                     硬盘分区表丢失、修复大事记--分区表修复利器testdisk
# 4      91                                            vi编辑器命令
# ..    ...                                                ...
# 262  2604                            Pandas怎样对每个分组应用apply函数?
# 263  2615                                   推荐系统实现相似推荐的流程和资源
# 264  2623                              文章写的好，但是没人看，原来标题可以这么写
# 265  2629                                             自律使我自由
# 266  2637                                      程序员-颈椎病-该练八段锦
#
#                                                  words  \
# 0    javascript select 元素 option 操作 javascript 删除 所...
# 1    当用 header 方法 输出 内容 出现 cannot modify header inf...
# 2    linux 禁止 机箱 蜂鸣 方法 图像 界面 注意 图形界面 即使 图像 界面 快捷键 出...
# 3    硬盘分区 丢失 修复 大事记 -- 分区表 修复 利器 testdisk 今天 2009 1...
# 4    vi 编辑器 命令 vi 编辑器 文字说明 模式 命令 模式 编辑 模式 末行 模式 切换 ...
# ..                                                 ...
# 262  pandas 怎样 每个 分组 应用 apply 函数 pandas 怎样 每个 分组 应用...
# 263  推荐 系统 实现 相似 推荐 流程 资源 视频 位于 链接 需要 资源 整理 视频 涉及 相...
# 264  文章 但是 没人 原来 标题 可以 这么 一种 方法 就是 三段式 标题 三段式 来自 百度...
# 265  自律 自由 从来 没有 完全 自由 如果 节制 放纵 自己 大吃大喝 熬夜 玩游戏 那么 导...
# 266                                     程序员 颈椎病 该练 八段锦
#
#                                             doc_vector  sim_vlaue  sim_value
# 0    [-0.013126199999999996, -0.03166106249999995, ...   0.953236   0.953236
# 1    [0.173896275, -0.12689985, -0.0503381250000000...   0.868788   0.868788
# 2    [0.17765841463414633, -0.13135253658536586, -0...   0.783414   0.783414
# 3    [0.25020975, -0.19336403888888903, -0.00018789...   0.724130   0.724130
# 4    [0.12497060176991134, -0.09836270353982311, 0....   0.798271   0.798271
# ..                                                 ...        ...        ...
# 262  [0.06635910714285706, 0.02634534761904762, -0....   0.978439   0.978439
# 263  [0.08312790909090909, -0.005004499999999976, -...   0.896456   0.896456
# 264  [0.22609510322580648, -0.18270135483870972, -0...   0.734370   0.734370
# 265  [0.19995407407407392, -0.30916040740740725, -0...   0.591319   0.591319
# 266  [0.58515775, -0.3567525, -0.03915575, -0.25169...   0.428904   0.428904
#
# [267 rows x 6 columns]

# %%
df.sort_values("sim_value",ascending=False)
# Out:
#        id                     post_title  \
# 256  2583            Pandas实现数据的合并concat
# 252  2546             Pandas的axis参数怎么理解？
# 255  2574           Pandas的Index索引有什么用途？
# 259  2594            Pandas怎样实现对数据的分组统计？
# 240  2502  Pandas系列-DataFrame和Series数据结构
# ..    ...                            ...
# 233  2404                    听樊登的《非暴力沟通》
# 87    655               情理之中又意料之外的超强减肥方法
# 41    206                     对自己将来的一些思考
# 265  2629                         自律使我自由
# 266  2637                  程序员-颈椎病-该练八段锦
#
#                                                  words  \
# 256  pandas 实现 数据 合并 concat 使用 场景 批量 合并 相同 格式 excel...
# 252  pandas axis 参数 怎么 理解 axis 参数 非常 困惑 难以 理解 视频 我会...
# 255  pandas index 索引 什么 用途 数据 存储 普通 column 用于 数据 查询...
# 259  pandas 怎样 实现 数据 分组 统计 pandas 怎样 实现 groupby 分组 ...
# 240  pandas 系列 dataframe series 数据结构 代码 演示 pandas 读...
# ..                                                 ...
# 233  樊登 非暴力 沟通 最近 爱奇艺 知识 课程 樊登教 快乐 事业有成 第一节 樊登 非暴力 ...
# 87   情理之中 意料之外 超强 减肥 方法 今天 人人 看到 很多 分享 一个 减肥 秘技 页面 ...
# 41   自己 将来 一些 思考 今天 看到 一篇 文章 名字 直白 可以 鞭策 一辈子 文章 不看 ...
# 265  自律 自由 从来 没有 完全 自由 如果 节制 放纵 自己 大吃大喝 熬夜 玩游戏 那么 导...
# 266                                     程序员 颈椎病 该练 八段锦
#
#                                             doc_vector  sim_vlaue  sim_value
# 256  [0.005996356060606063, 0.0679557373737372, -0....   1.000000   1.000000
# 252  [0.014649806701030969, -0.03124717268041237, 0...   0.988473   0.988473
# 255  [0.003863167832167842, 0.018865074592074583, -...   0.987658   0.987658
# 259  [0.023095106583072046, 0.06942839289446184, 0....   0.987287   0.987287
# 240  [0.06663766445182721, 0.04775676744186041, -0....   0.979710   0.979710
# ..                                                 ...        ...        ...
# 233  [0.19294547674418594, -0.20212805813953494, -0...   0.613794   0.613794
# 87   [0.18228809202453974, -0.348092773006135, 0.00...   0.612966   0.612966
# 41   [0.19904671929824563, -0.24740909356725144, -0...   0.605805   0.605805
# 265  [0.19995407407407392, -0.30916040740740725, -0...   0.591319   0.591319
# 266  [0.58515775, -0.3567525, -0.03915575, -0.25169...   0.428904   0.428904
#
# [267 rows x 6 columns]
