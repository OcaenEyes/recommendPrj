# %% [markdown]
# ### 知识：
#
# 1. word2vec：输入(doc, words)，得到word embedding
# 2. item2vec：输入（userid, itemids），得到item embedding
#
# 说明：
#
# 1. 使用标题/内容的分词embedding作推荐，属于内容相似推荐
# 2. 使用行为列表作embedding作推荐，属于行为相关推荐，效果比内容相似推荐更好
#
# 延伸：
#
# 1. 把word embedding进行加和、平均，就得到了document embedding；
# 2. 把item embedding进行加和、平均，就得到了user embedding；

# %% [markdown]
# #### 数据整理

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("./dataset/datas/ml-latest-small/ratings.csv")

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
# 取评分大于均值的数据
df_new = df[df["rating"] >= df["rating"].mean()]

# %%
df_new
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100830     610   166528     4.0  1493879365
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [48580 rows x 4 columns]

# %%
# 按照用户id聚合，得到userid， movieids
df_group = df_new.groupby("userId")["movieId"].apply(lambda x : " ".join([str(m) for m in x])).reset_index()

# %%
df_group
# Out:
#      userId                                            movieId
# 0         1  1 3 6 47 50 101 110 151 157 163 216 231 235 26...
# 1         2  333 1704 3578 6874 46970 48516 58559 60756 681...
# 2         3  849 1587 2288 2851 3024 3703 4518 5181 5746 57...
# 3         4  106 125 162 176 215 232 260 265 319 342 345 34...
# 4         5  1 21 34 36 50 58 110 232 247 261 290 296 367 4...
# ..      ...                                                ...
# 604     606  17 18 29 32 46 50 68 70 73 80 82 147 154 156 1...
# 605     607  1 36 86 110 150 165 188 241 292 318 366 377 38...
# 606     608  10 16 47 50 110 170 172 293 296 318 333 353 38...
# 607     609           10 253 296 318 356 457 590 731 1150 1161
# 608     610  1 6 16 32 47 50 70 110 111 112 194 215 231 260...
#
# [609 rows x 2 columns]

# %%
df_group.to_csv("./df_userid_movieids.csv",index=False)

# %% [markdown]
# #### pyspark.ml  word2vec

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .appName("pyspark item2vec") \
        .getOrCreate()

# %%
sc = spark.sparkContext

# %%
from pyspark.ml.feature import Word2Vec
import  pyspark.sql.functions as F

# %%
df_uid_movieids = spark.read.csv("./df_userid_movieids.csv",header=True)

# %%
df_uid_movieids.show(5)
# Out:
# +------+--------------------+
# |userId|             movieId|
# +------+--------------------+
# |     1|1 3 6 47 50 101 1...|
# |     2|333 1704 3578 687...|
# |     3|849 1587 2288 285...|
# |     4|106 125 162 176 2...|
# |     5|1 21 34 36 50 58 ...|
# +------+--------------------+
# only showing top 5 rows

# %%
df_uid_movieids = df_uid_movieids.withColumn("movie_ids", F.split(df_uid_movieids.movieId," "))

# %%
df_uid_movieids.show(5)
# Out:
# +------+--------------------+--------------------+
859663,-0.013635413721203804,-0.005638391710817814,-0.024320395663380623,0.01732165552675724,0.023215053603053093,0.004519939422607422,-0.0240644421428442,0.014922845177352428,-0.0137821389362216,-0.001530394540168345,-0.036699797958135605,0.02657640166580677,-0.024594159796833992,-0.013430873863399029,-0.005073125008493662,0.009853401221334934,0.008068307302892208,-0.03873148560523987,-0.030880365520715714,0.05173838138580322,0.016477275639772415,-0.027388574555516243,0.02470317669212818,0.03227768465876579,-0.008410640060901642,0.022074755281209946,-0.006131336092948914,-0.005369914695620537,-0.03967980667948723,-0.02268120087683201,-0.026518885046243668,0.02642941102385521,0.004859814886003733,0.0015498180873692036,-0.005820570047944784,0.0013806738425046206,-2.578167477622628E-4,0.015818921849131584,-0.022948795929551125,-0.01312775257974863,0.026006408035755157,-0.006779080256819725,0.011667760089039803,0.05349916219711304,0.018069712445139885,0.01672985590994358,-0.03337022289633751]                                       |
# +-----+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 3 rows

# %%
df_movie_embedding = model.getVectors().select("word","vector") \
        .toPandas()

# %%
df_movie_embedding
# Out:
#         word                                             vector
# 0      26985  [0.003629797138273716, -0.009563547559082508, ...
# 1       5451  [0.0030522325541824102, -0.012606758624315262,...
# 2       4018  [0.020170560106635094, -0.02727970853447914, 0...
# 3       4056  [0.014343895018100739, -0.02686471678316593, 0...
# 4      32584  [0.0016515108291059732, -0.024230409413576126,...
# ...      ...                                                ...
# 6293  104419  [0.004192105028778315, -0.008962797001004219, ...
# 6294  133867  [0.006182205863296986, -0.018061960116028786, ...
# 6295    3439  [0.0035319188609719276, -0.004911014810204506,...
# 6296    2141  [0.006646751891821623, -0.018658487126231194, ...
# 6297  111364  [0.004464089870452881, -0.0032871183939278126,...
#
# [6298 rows x 2 columns]

# %% [markdown]
# ##### 对于给定电影算出最相似的10个电影

# %%
df_movie = pd.read_csv("./dataset/datas/ml-latest-small/movies.csv")

# %%
df_movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
df_movie["movieId"] =df_movie["movieId"].astype(str)

# %%
df_merge = pd.merge(left=df_movie_embedding,right=df_movie, left_on="word",right_on="movieId")

# %%
df_merge.columns
# Out:
# Index(['word', 'vector', 'movieId', 'title', 'genres'], dtype='object')

# %%
df_merge = df_merge[['movieId', 'title', 'genres', 'vector']]

# %%
df_merge
# Out:
#      movieId                                              title  \
# 0      26985                                     Nirvana (1997)
# 1       5451                                     Pumpkin (2002)
# 2       4018                             What Women Want (2000)
# 3       4056                                 Pledge, The (2001)
# 4      32584                Ballad of Jack and Rose, The (2005)
# ...      ...                                                ...
# 6293  104419        Justice League: Crisis on Two Earths (2010)
# 6294  133867                               Barely Lethal (2015)
# 6295    3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 6296    2141                           American Tail, An (1986)
# 6297  111364                                    Godzilla (2014)
#
#                                    genres  \
# 0                           Action|Sci-Fi
# 1                    Comedy|Drama|Romance
# 2                          Comedy|Romance
# 3            Crime|Drama|Mystery|Thriller
# 4                                   Drama
# ...                                   ...
# 6293              Action|Animation|Sci-Fi
# 6294              Action|Adventure|Comedy
# 6295              Action|Children|Fantasy
# 6296  Adventure|Animation|Children|Comedy
# 6297         Action|Adventure|Sci-Fi|IMAX
#
#                                                  vector
# 0     [0.003629797138273716, -0.009563547559082508, ...
# 1     [0.0030522325541824102, -0.012606758624315262,...
# 2     [0.020170560106635094, -0.02727970853447914, 0...
# 3     [0.014343895018100739, -0.02686471678316593, 0...
# 4     [0.0016515108291059732, -0.024230409413576126,...
# ...                                                 ...
# 6293  [0.004192105028778315, -0.008962797001004219, ...
# 6294  [0.006182205863296986, -0.018061960116028786, ...
# 6295  [0.0035319188609719276, -0.004911014810204506,...
# 6296  [0.006646751891821623, -0.018658487126231194, ...
# 6297  [0.004464089870452881, -0.0032871183939278126,...
#
# [6298 rows x 4 columns]

# %%
# 选定一个电影 104419
movie_id= "104419"

# %%
df_merge[df_merge["movieId"]== movie_id]
# Out:
#      movieId                                        title  \
# 6293  104419  Justice League: Crisis on Two Earths (2010)
#
#                        genres  \
# 6293  Action|Animation|Sci-Fi
#
#                                                  vector
# 6293  [0.004192105028778315, -0.008962797001004219, ...

# %%
df_merge[df_merge["movieId"]== movie_id]["vector"].iloc[0]
# Out:
# DenseVector([0.0042, -0.009, 0.0134, -0.003, 0.0051, -0.0008, 0.0002, -0.0124, -0.0081, -0.0033, 0.0022, 0.0116, -0.0086, 0.0179, 0.0033, 0.0055, -0.0047, -0.0042, -0.0048, -0.0124, 0.0008, 0.0051, -0.0065, -0.0007, 0.0053, -0.0009, -0.0082, -0.0064, -0.0031, -0.008, -0.0067, -0.0026, -0.001, -0.0188, -0.0061, -0.0003, -0.0242, 0.0021, -0.0008, 0.0015, 0.0132, -0.0015, 0.0109, -0.0106, 0.003, 0.0183, -0.0086, 0.006, -0.0003, -0.0169, 0.0035, 0.0136, -0.0033, 0.0061, -0.0102, 0.0072, 0.0014, 0.0044, 0.0039, -0.0186, 0.0072, -0.0089, 0.0003, -0.0096, 0.0001, -0.001, -0.0024, 0.0089, 0.0048, 0.018, -0.0014, 0.0073, 0.0035, 0.0142, 0.0032, 0.0192, -0.0089, -0.0064, -0.0079, 0.0066, -0.0113, -0.0011, -0.002, 0.0, 0.0089, 0.0044, 0.0027, 0.0013, 0.004, 0.0098, -0.0041, -0.0103, -0.0053, -0.0079, 0.0081, 0.021, 0.0085, 0.0233, 0.0078, -0.0068])

# %%
target_movie_emb= df_merge[df_merge["movieId"]== movie_id]["vector"].iloc[0]

# %%
# 余弦相似度， 与target——movieid 104419的相似度
from scipy.spatial import distance
df_merge["sim_value"] = df_merge["vector"].map(lambda x : 1- distance.cosine(target_movie_emb,x))

# %%
df_merge
# Out:
#      movieId                                              title  \
# 0      26985                                     Nirvana (1997)
# 1       5451                                     Pumpkin (2002)
# 2       4018                             What Women Want (2000)
# 3       4056                                 Pledge, The (2001)
# 4      32584                Ballad of Jack and Rose, The (2005)
# ...      ...                                                ...
# 6293  104419        Justice League: Crisis on Two Earths (2010)
# 6294  133867                               Barely Lethal (2015)
# 6295    3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 6296    2141                           American Tail, An (1986)
# 6297  111364                                    Godzilla (2014)
#
#                                    genres  \
# 0                           Action|Sci-Fi
# 1                    Comedy|Drama|Romance
# 2                          Comedy|Romance
# 3            Crime|Drama|Mystery|Thriller
# 4                                   Drama
# ...                                   ...
# 6293              Action|Animation|Sci-Fi
# 6294              Action|Adventure|Comedy
# 6295              Action|Children|Fantasy
# 6296  Adventure|Animation|Children|Comedy
# 6297         Action|Adventure|Sci-Fi|IMAX
#
#                                                  vector  sim_value
# 0     [0.003629797138273716, -0.009563547559082508, ...   0.779945
# 1     [0.0030522325541824102, -0.012606758624315262,...   0.694744
# 2     [0.020170560106635094, -0.02727970853447914, 0...   0.423213
# 3     [0.014343895018100739, -0.02686471678316593, 0...   0.878688
# 4     [0.0016515108291059732, -0.024230409413576126,...   0.731997
# ...                                                 ...        ...
# 6293  [0.004192105028778315, -0.008962797001004219, ...   1.000000
# 6294  [0.006182205863296986, -0.018061960116028786, ...   0.881353
# 6295  [0.0035319188609719276, -0.004911014810204506,...   0.021747
# 6296  [0.006646751891821623, -0.018658487126231194, ...   0.707335
# 6297  [0.004464089870452881, -0.0032871183939278126,...   0.562878
#
# [6298 rows x 5 columns]

# %%
# 按相似度降序排列，查询前10条
df_merge.sort_values("sim_value",ascending=False)[['movieId', 'title', 'genres','sim_value']].head(10)
# Out:
#      movieId                                              title  \
# 6293  104419        Justice League: Crisis on Two Earths (2010)
# 3767  142488                                   Spotlight (2015)
# 3700    7123                                 Naked Lunch (1991)
# 5207    5417               Fast Runner, The (Atanarjuat) (2001)
# 4010   64285  Wallace and Gromit in 'A Matter of Loaf and De...
# 1742    7745  Scent of Green Papaya, The (Mùi du du xhan - L...
# 1121   27266                                        2046 (2004)
# 1521  140359              Doctor Who: The Waters of Mars (2009)
# 1003    3615                                    Dinosaur (2000)
# 3305  150596      Doctor Who: The Husbands of River Song (2015)
#
#                             genres  sim_value
# 6293       Action|Animation|Sci-Fi   1.000000
# 3767                      Thriller   0.929320
# 3700  Drama|Fantasy|Mystery|Sci-Fi   0.927734
# 5207                 Drama|Fantasy   0.927640
# 4010              Animation|Comedy   0.926281
# 1742                         Drama   0.925655
# 1121  Drama|Fantasy|Romance|Sci-Fi   0.924621
# 1521     Adventure|Children|Sci-Fi   0.923434
# 1003  Adventure|Animation|Children   0.922888
# 3305           Comedy|Drama|Sci-Fi   0.922632
